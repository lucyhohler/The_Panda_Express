# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Setting Datasets

#Quarterback Data
QB2010to2015 = "Raw/NFL_Combined/QB_2010_to_2015.csv"

#Runingback Data
RB2010to2015 = "Raw/NFL_Combined/RB_2010_to_2015.csv"

#LB Data
OLB2010to2015 = "Raw/NFL_Combined/OLB_2010_to_2015.csv"
ILB2010to2015 = "Raw/NFL_Combined/ILB_2010_to_2015.csv"

#Defensive Line Data
DL2010 = "Raw/NFL_Combined/DL2010.csv"
DL2011 = "Raw/NFL_Combined/DL2011.csv"
DL2012 = "Raw/NFL_Combined/DL2012.csv"
DL2013 = "Raw/NFL_Combined/DL2013.csv"
DL2014 = "Raw/NFL_Combined/DL2014.csv"
DL2015 = "Raw/NFL_Combined/DL2015.csv"

#OL Data
OL2010to2013 = "Raw/NFL_Combined/OL2010_2013.csv"
OL2014to2015 = "Raw/NFL_Combined/OL2014_2015.csv"

#TE Data
TE2010to2015 = "Raw/NFL_Combined/TE2010_2015.csv"

#Receiver Data
WR2010to2013 = "Raw/NFL_Combined/WR2010_2013.csv"
WR2014to2015 = "Raw/NFL_Combined/WR2014_2015.csv"

#Defensive Backs Data
FS2010to2015 = "Raw/NFL_Combined/FS2010to2015.csv"
SS2010to2015 = "Raw/NFL_Combined/SS2010to2015.csv"
CB2010to2012 = "Raw/NFL_Combined/CB2010to2012.csv"
CB2013to2015 = "Raw/NFL_Combined/CB2013to2015.csv"

#Pro Bowl Data
PB2011 = "Raw/Pro_Bowl/ProBowl2011.csv"
PB2012 = "Raw/Pro_Bowl/ProBowl2012.csv"
PB2013 = "Raw/Pro_Bowl/ProBowl2013.csv"
PB2014 = "Raw/Pro_Bowl/ProBowl2014.csv"
PB2015 = "Raw/Pro_Bowl/ProBowl2015.csv"
PB2016 = "Raw/Pro_Bowl/ProBowl2016.csv"
PB2017 = "Raw/Pro_Bowl/ProBowl2017.csv"
PB2018 = "Raw/Pro_Bowl/ProBowl2018.csv"

# %%
#Loading into DataFrame

#QB DataFrame
QB_2010to2015_df = pd.read_csv(QB2010to2015, encoding="utf-8")

#RB DataFrame
RB_2010to2015_df = pd.read_csv(RB2010to2015, encoding="utf-8")

#LB DataFrames
ILB_2010to2015_df = pd.read_csv(ILB2010to2015, encoding="utf-8")
OLB_2010to2015_df = pd.read_csv(OLB2010to2015, encoding="utf-8")

#DL DataFrame
DL_2010_df = pd.read_csv(DL2010, encoding="utf-8")
DL_2011_df = pd.read_csv(DL2011, encoding="utf-8")
DL_2012_df = pd.read_csv(DL2012, encoding="utf-8")
DL_2013_df = pd.read_csv(DL2013, encoding="utf-8")
DL_2014_df = pd.read_csv(DL2014, encoding="utf-8")
DL_2015_df = pd.read_csv(DL2015, encoding="utf-8")

#DB DataFrame
FS_2010to2015_df = pd.read_csv(FS2010to2015, encoding="utf-8")
SS_2010to2015_df = pd.read_csv(SS2010to2015, encoding="utf-8")
CB_2010to2012_df = pd.read_csv(CB2010to2012, encoding="utf-8")
CB_2013to2015_df = pd.read_csv(CB2013to2015, encoding="utf-8")

#OL DataFrame
OL2010to2013_df = pd.read_csv(OL2010to2013, encoding="utf-8")
OL2014to2015_df = pd.read_csv(OL2014to2015, encoding="utf-8")

#TE DataFrame
TE2010to2015_df = pd.read_csv(TE2010to2015, encoding="utf-8")

#WR DataFrame
WR2010to2013_df = pd.read_csv(WR2010to2013, encoding="utf-8")
WR2014to2015_df = pd.read_csv(WR2014to2015, encoding="utf-8")

#ProBowl DataFrames
PB2011_df = pd.read_csv(PB2011, encoding='utf-8')
PB2012_df = pd.read_csv(PB2012, encoding='utf-8')
PB2013_df = pd.read_csv(PB2013, encoding='utf-8')
PB2014_df = pd.read_csv(PB2014, encoding='utf-8')
PB2015_df = pd.read_csv(PB2015, encoding='utf-8')
PB2016_df = pd.read_csv(PB2016, encoding='utf-8')
PB2017_df = pd.read_csv(PB2017, encoding='utf-8')
PB2018_df = pd.read_csv(PB2018, encoding='utf-8')

# %%
# Replacing names of positions for easier data analysis

#Offensive tackle & offensive guard converted to offensive line allocation
OL2010to2013_df['Pos'] = OL2010to2013_df['Pos'].replace({'OG': 'OL', 'OT': 'OL'})
OL2014to2015_df['Pos'] = OL2014to2015_df['Pos'].replace({'OG': 'OL', 'OT': 'OL'})

#Outside linebacker & inside linebacker converted to general Linebacker allocation
ILB_2010to2015_df['Pos'] = ILB_2010to2015_df['Pos'].replace({'OLB': 'LB', 'ILB': 'LB'})
OLB_2010to2015_df['Pos'] = OLB_2010to2015_df['Pos'].replace({'OLB': 'LB', 'ILB': 'LB'})

#Defensive end & defensive tackle converted to defensive line allocation
DL_2010_df['Pos'] = DL_2010_df['Pos'].replace(
   {'DE': 'DL', 'DT': 'DL'})
DL_2011_df['Pos'] = DL_2011_df['Pos'].replace(
   {'DE': 'DL', 'DT': 'DL'})
DL_2012_df['Pos'] = DL_2012_df['Pos'].replace(
   {'DE': 'DL', 'DT': 'DL'})
DL_2013_df['Pos'] = DL_2013_df['Pos'].replace(
   {'DE': 'DL', 'DT': 'DL'})   
DL_2014_df['Pos'] = DL_2014_df['Pos'].replace(
   {'DE': 'DL', 'DT': 'DL'})
DL_2015_df['Pos'] = DL_2015_df['Pos'].replace(
   {'DE': 'DL', 'DT': 'DL'})

#Cornerbacks and Safeties converted to defensive back allocation
FS_2010to2015_df['Pos'] = FS_2010to2015_df['Pos'].replace(
   {'FS': 'DB'})
SS_2010to2015_df['Pos'] = SS_2010to2015_df['Pos'].replace(
   {'SS': 'DB'})
CB_2010to2012_df['Pos'] = CB_2010to2012_df['Pos'].replace(
    {'CB': 'DB'})
CB_2013to2015_df['Pos'] = CB_2013to2015_df['Pos'].replace(
    {'CB': 'DB'})

# %%
#Merging DataFrames
merge1_DL = DL_2010_df.append(DL_2011_df, ignore_index=True)
merge2_DL = merge1_DL.append(DL_2012_df, ignore_index=True)
merge3_DL = merge2_DL.append(DL_2013_df, ignore_index=True)
merge4_DL = merge3_DL.append(DL_2014_df, ignore_index=True)
master_DL = merge4_DL.append(DL_2015_df, ignore_index=True)

#Merging DB DataFrames; use of multiple files; using for function
master_DB = FS_2010to2015_df
DBFiles = [SS_2010to2015_df, CB_2010to2012_df, CB_2013to2015_df]

for DBFile in DBFiles:
    master_DB = master_DB.append(DBFile, ignore_index=True)

#Merging PB DataFrames; use of multiple files; using for function 
master_PB = PB2011_df
PBFiles = [PB2013_df,PB2014_df,PB2015_df,PB2016_df,PB2017_df, PB2018_df]

for PBFile in PBFiles:
    master_PB = master_PB.append(PBFile, ignore_index=True)

#Merging LB DataFrames;
master_LB = ILB_2010to2015_df.append(OLB_2010to2015_df, ignore_index=True)

#Merging OL DataFrames;
master_OL = OL2010to2013_df.append(OL2014to2015_df, ignore_index=True)

#Merging WR DataFrames;
master_WR = WR2010to2013_df.append(WR2014to2015_df, ignore_index=True)

# %%
#Cleaning Data;

#Pulling the categories we need from each master positon list
master_DB = master_DB[['Year','Player','Pos','Height',"Wt",'40YD','Vertical','BenchReps','Broad Jump','3Cone','Shuttle']]
master_DL = master_DL[['Year','Player','Pos','Height',"Wt",'40YD','Vertical','BenchReps','Broad Jump','3Cone','Shuttle']]
master_OL = master_OL[['Year','Player','Pos','Height',"Wt",'40YD','Vertical','BenchReps','Broad Jump','3Cone','Shuttle']]
master_LB = master_LB[['Year','Player','Pos','Height',"Wt",'40YD','Vertical','BenchReps','Broad Jump','3Cone','Shuttle']]
master_WR = master_WR[['Year','Player','Pos','Height',"Wt",'40YD','Vertical','BenchReps','Broad Jump','3Cone','Shuttle']]
master_QB = QB_2010to2015_df[['Year','Player','Pos','Height',"Wt",'40YD','Vertical','BenchReps','Broad Jump','3Cone','Shuttle']]
master_RB = RB_2010to2015_df[['Year','Player','Pos','Height',"Wt",'40YD','Vertical','BenchReps','Broad Jump','3Cone','Shuttle']]
master_TE = TE2010to2015_df[['Year','Player','Pos','Height',"Wt",'40YD','Vertical','BenchReps','Broad Jump','3Cone','Shuttle']]

#Cleaning ProBowl names; taking out the '+' and '%'
master_PB.Player = [x.strip('+') for x in master_PB.Player]
master_PB.Player = [x.strip('%') for x in master_PB.Player]

#Pulling only the Player names
master_PB = master_PB[['Player']]

# %%
#Creating the master file with all positions

df = QB2010to2015
df = pd.read_csv(df, encoding="utf-8")

filenames = [RB2010to2015, OLB2010to2015, ILB2010to2015, DL2010, DL2011, DL2012, DL2013, DL2014,
            DL2015, OL2010to2013, OL2014to2015, TE2010to2015, WR2010to2013, WR2014to2015, FS2010to2015,
            SS2010to2015, CB2010to2012, CB2013to2015]

for filename in filenames:
    df = df.append(pd.read_csv(filename), ignore_index=True)

df = df[['Year','Player','Pos','Height',"Wt",'40YD','Vertical','BenchReps','Broad Jump','3Cone','Shuttle']]

df['Pos'] = df['Pos'].replace({'OG': 'OL', 'OT': 'OL', 'OLB': 'LB', 'ILB': 'LB', 'DE': 'DL', 'DT': 'DL', 'FS': 'DB',
                              'SS': 'DB', 'CB': 'DB'})

df['ProBowl Appearances'] = df['Player'].map(master_PB['Player'].value_counts())

master_ALL = df.sort_values(['ProBowl Appearances'], ascending=False)

# %%
#Creating a new row 'ProBowl Appearances' and taking a value count for how many times their names appear in the master_PB file
master_DL['ProBowl Appearances'] = master_DL['Player'].map(master_PB['Player'].value_counts())
master_DB['ProBowl Appearances'] = master_DB['Player'].map(master_PB['Player'].value_counts())
master_WR['ProBowl Appearances'] = master_WR['Player'].map(master_PB['Player'].value_counts())
master_LB['ProBowl Appearances'] = master_LB['Player'].map(master_PB['Player'].value_counts())
master_RB['ProBowl Appearances'] = master_RB['Player'].map(master_PB['Player'].value_counts())
master_OL['ProBowl Appearances'] = master_OL['Player'].map(master_PB['Player'].value_counts())
master_QB['ProBowl Appearances'] = master_QB['Player'].map(master_PB['Player'].value_counts())
master_TE['ProBowl Appearances'] = master_TE['Player'].map(master_PB['Player'].value_counts())
# Out:
# C:\Users\lucyh\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\lucyh\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\lucyh\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#Creating the graphs

#EXPERIMENTING WITH GRAPHS
plt.scatter(master_DB['3Cone'], master_DB['Shuttle'], s=master_DB['ProBowl Appearances']*100, color = ['gold'], edgecolor = 'black', alpha = .75)
plt.scatter(master_WR['3Cone'], master_WR['Shuttle'], s=master_WR['ProBowl Appearances']*100, color = ['coral'], edgecolor = 'black', alpha = .75)
plt.grid()

#Observations; 3Cone sweet spot; maximum of 7 seconds
#Observations; Shuttle time sweet spot; maximum of 4.3 seconds

# %%
#3Cone and Broadjump; DB and WR
plt.scatter(master_DB['3Cone'], master_DB['Broad Jump'], s=master_DB['ProBowl Appearances']*100, color = ['gold'], edgecolor = 'black', alpha = .75)
plt.scatter(master_WR['3Cone'], master_WR['Broad Jump'], s=master_WR['ProBowl Appearances']*100, color = ['coral'], edgecolor = 'black', alpha = .75)
plt.grid()

#Observations; can see that a the sweet spot for Broad Jump was between 120 and 130 for most PB appearances
#Observations; sweet spot for 3cone time was a maximum of 7 seconds

# %%
#Speed and athletic ability
plt.scatter(master_LB['40YD'], master_LB['Broad Jump'], s=master_LB['ProBowl Appearances']*100, color = ['gold'], edgecolor = 'black', alpha = .75)
plt.scatter(master_WR['40YD'], master_WR['Broad Jump'], s=master_WR['ProBowl Appearances']*100, color = ['coral'], edgecolor = 'black', alpha = .75)
plt.scatter(master_DB['40YD'], master_DB['Broad Jump'], s=master_DB['ProBowl Appearances']*100, color = ['blue'], edgecolor = 'black', alpha = .75)
plt.scatter(master_QB['40YD'], master_QB['Broad Jump'], s=master_QB['ProBowl Appearances']*100, color = ['purple'], edgecolor = 'black', alpha = .75)
plt.scatter(master_RB['40YD'], master_RB['Broad Jump'], s=master_RB['ProBowl Appearances']*100, color = ['black'], edgecolor = 'black', alpha = .75)
plt.scatter(master_TE['40YD'], master_TE['Broad Jump'], s=master_TE['ProBowl Appearances']*100, color = ['brown'], edgecolor = 'black', alpha = .75)
plt.grid()

#Speed and athleticism is of the essence and players who ran a 40 Yard in less than 4.7 sec and have a broad jump of at least 110
#have a bigger chance of making it to the Probowl.

#Here we look at general athleticism needed to succeed in NFL;
#Biggest correlation between a minimum of 4.6 second 40 yard; and 120 to 130 range of broad jump
#Needed; legend guide for color -> position | Title: Correlation between Broad Jump and 40 Yard.

# %%
#Weight and Strength
plt.scatter(master_OL['Wt'], master_OL['BenchReps'], s=master_OL['ProBowl Appearances']*100, color = ['red'], edgecolor = 'black', alpha = .75)
plt.scatter(master_DL['Wt'], master_DL['BenchReps'], s=master_DL['ProBowl Appearances']*100, color = ['green'], edgecolor = 'black', alpha = .75)
plt.grid()

#Defensive and Offensive Line - Players in these position are very strong and build like a truck.
#For these positions/players to make it to the Probowl, there is a correlation with weight between 
#280 and 320 and also being able to do Bench press reps from 20 to 35

##Here we look at weight and bench press in the trenchs (Offensive Line and Defensive Line);
#Biggest correlation between of a weight between 300-320 and bench of 25-30.
#Needed; legend guide for color -> position | Title: Correlation between weight and bench press (Offensive Line and Defensive Line)

# %%
#Speed and quickness
plt.scatter(master_LB['40YD'], master_LB['Shuttle'], s=master_LB['ProBowl Appearances']*100, color = ['gold'], edgecolor = 'black', alpha = .75)
plt.scatter(master_WR['40YD'], master_WR['Shuttle'], s=master_WR['ProBowl Appearances']*100, color = ['coral'], edgecolor = 'black', alpha = .75)
plt.scatter(master_DB['40YD'], master_DB['Shuttle'], s=master_DB['ProBowl Appearances']*100, color = ['blue'], edgecolor = 'black', alpha = .75)
plt.scatter(master_QB['40YD'], master_QB['Shuttle'], s=master_QB['ProBowl Appearances']*100, color = ['purple'], edgecolor = 'black', alpha = .75)
plt.scatter(master_RB['40YD'], master_RB['Shuttle'], s=master_RB['ProBowl Appearances']*100, color = ['black'], edgecolor = 'black', alpha = .75)
plt.scatter(master_TE['40YD'], master_TE['Shuttle'], s=master_TE['ProBowl Appearances']*100, color = ['brown'], edgecolor = 'black', alpha = .75)
plt.grid()

#Run a 40 yard in less than 4.7 seconds and a shuttle in less than 4.5 seconds increases a players chances
#of making it to the Probowl.

#Using first graph; NOT NEEDED

# %%
#Creating variables for amount of appearances in pro bowl (per position) and amount of players who made the pro bowl (per position)

#Quarterback total appearances/total players
QB_probowl_appearances = master_QB['ProBowl Appearances'].sum()
QB_probowl_players = master_QB['ProBowl Appearances'].count()

#Runningback total appearances/total players
RB_probowl_appearances = master_RB['ProBowl Appearances'].sum()
RB_probowl_players = master_RB['ProBowl Appearances'].count()

#Receivers total appearances/total players
WR_probowl_appearances = master_WR['ProBowl Appearances'].sum()
WR_probowl_players = master_WR['ProBowl Appearances'].count()

#Offensive line total appearances/total players
OL_probowl_appearances = master_OL['ProBowl Appearances'].sum()
OL_probowl_players = master_OL['ProBowl Appearances'].count()

#Tight end total appearances/total players
TE_probowl_appearances = master_TE['ProBowl Appearances'].sum()
TE_probowl_players = master_TE['ProBowl Appearances'].count()

#Defensive line total appearances/total players
DL_probowl_appearances = master_DL['ProBowl Appearances'].sum()
DL_probowl_players = master_DL['ProBowl Appearances'].count()

#Linebackers total appearances/total players
LB_probowl_appearances = master_LB['ProBowl Appearances'].sum()
LB_probowl_players = master_LB['ProBowl Appearances'].count()

#Defensive backs total appearances/total players
DB_probowl_appearances = master_DB['ProBowl Appearances'].sum()
DB_probowl_players = master_DB['ProBowl Appearances'].count()

# %%
#Number of Probowl players by position
bar_players = [QB_probowl_players, RB_probowl_players, WR_probowl_players, LB_probowl_players, 
         OL_probowl_players, DB_probowl_players, DL_probowl_players, TE_probowl_players]

x_axis = np.arange(len(bar_players))
plt.bar(x_axis, bar_players, color='b', alpha=0.5, align="center")

tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["Quarterbacks", "Runningbacks", "Wide receivers", "Linebackers", "Offensive Line", 
                            "Defensive Backs", "Defensive Line", "Tight End"], rotation=45, ha="right")

plt.show()

#The defensive Line has made the most probowl players, followed by the Defensive Backs and the Wide Receivers.

# %%
#Number of Probowl appearances by position
bar_appearances = [QB_probowl_appearances, RB_probowl_appearances, WR_probowl_appearances, LB_probowl_appearances, 
         OL_probowl_appearances, DB_probowl_appearances, DL_probowl_appearances, TE_probowl_appearances]

x_axis = np.arange(len(bar_appearances))
plt.bar(x_axis, bar_appearances, color='g', alpha=0.5, align="center")

tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["Quarterbacks", "Runningbacks", "Wide receivers", "Linebackers", "Offensive Line", 
                            "Defensive Backs", "Defensive Line", "Tight End"], rotation=45, ha="right")

plt.show()

#The defensive Line has made the most probowl appearances, followed by the Defensive Backs and the Wide Receivers.

# %%
#Creating a pie chart to see what positions made the most pro bowls

#Setting the labels for the graph
labels = 'Quarterbacks', 'Runningbacks', 'Receivers', 'Offensive Line', 'Tight End', 'Defensive Line', 'Linebackers', 'Defensive Backs'

#Setting the amounts for the graph
sizes = [QB_probowl_players, RB_probowl_players, WR_probowl_players, OL_probowl_players, TE_probowl_players, DL_probowl_players,
        LB_probowl_players, DB_probowl_players]

#Making the highest %'s stick out more
explode = (0, 0, 0.1, 0, 0, 0.1, 0, 0.1)

#Plug it in
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=140)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

plt.savefig('PBAppearances_Postional')
#Here we look at the most successful postiions within the years we studied (2010 to 2015);
#Needed; Title: Most pro bowl appearances by positions (2010 to 2015)

# %%
#DF by Position
QB_Pos = master_ALL.loc[master_ALL["Pos"] == "QB"] 
RB_Pos = master_ALL.loc[master_ALL["Pos"] == "RB"] 
OL_Pos = master_ALL.loc[master_ALL["Pos"] == "OL"] 
LB_Pos = master_ALL.loc[master_ALL["Pos"] == "LB"] 
DL_Pos = master_ALL.loc[master_ALL["Pos"] == "DL"] 
DB_Pos = master_ALL.loc[master_ALL["Pos"] == "DB"] 
WR_Pos = master_ALL.loc[master_ALL["Pos"] == "WR"] 
TE_Pos = master_ALL.loc[master_ALL["Pos"] == "TE"]

# %%
#Avg by position by drill
QB_40 = QB_Pos["40YD"].mean()
QB_Vert = QB_Pos["Vertical"].mean()
QB_Bench = QB_Pos["BenchReps"].mean()
QB_Jump = QB_Pos["Broad Jump"].mean()
QB_3Cone = QB_Pos["3Cone"].mean()
QB_Shut = QB_Pos["Shuttle"].mean()

RB_40 = RB_Pos["40YD"].mean()
RB_Vert = RB_Pos["Vertical"].mean()
RB_Bench = RB_Pos["BenchReps"].mean()
RB_Jump = RB_Pos["Broad Jump"].mean()
RB_3Cone = RB_Pos["3Cone"].mean()
RB_Shut = RB_Pos["Shuttle"].mean()

OL_40 = OL_Pos["40YD"].mean()
OL_Vert = OL_Pos["Vertical"].mean()
OL_Bench = OL_Pos["BenchReps"].mean()
OL_Jump = OL_Pos["Broad Jump"].mean()
OL_3Cone = OL_Pos["3Cone"].mean()
OL_Shut = OL_Pos["Shuttle"].mean()

DL_40 = DL_Pos["40YD"].mean()
DL_Vert = DL_Pos["Vertical"].mean()
DL_Bench = DL_Pos["BenchReps"].mean()
DL_Jump = DL_Pos["Broad Jump"].mean()
DL_3Cone = DL_Pos["3Cone"].mean()
DL_Shut = DL_Pos["Shuttle"].mean()

DB_40 = DB_Pos["40YD"].mean()
DB_Vert = DB_Pos["Vertical"].mean()
DB_Bench = DB_Pos["BenchReps"].mean()
DB_Jump = DB_Pos["Broad Jump"].mean()
DB_3Cone = DB_Pos["3Cone"].mean()
DB_Shut = DB_Pos["Shuttle"].mean()

WR_40 = WR_Pos["40YD"].mean()
WR_Vert = WR_Pos["Vertical"].mean()
WR_Bench = WR_Pos["BenchReps"].mean()
WR_Jump = WR_Pos["Broad Jump"].mean()
WR_3Cone = WR_Pos["3Cone"].mean()
WR_Shut = WR_Pos["Shuttle"].mean()

TE_40 = TE_Pos["40YD"].mean()
TE_Vert = TE_Pos["Vertical"].mean()
TE_Bench = TE_Pos["BenchReps"].mean()
TE_Jump = TE_Pos["Broad Jump"].mean()
TE_3Cone = TE_Pos["3Cone"].mean()
TE_Shut = TE_Pos["Shuttle"].mean()

LB_40 = LB_Pos["40YD"].mean()
LB_Vert = LB_Pos["Vertical"].mean()
LB_Bench = LB_Pos["BenchReps"].mean()
LB_Jump = LB_Pos["Broad Jump"].mean()
LB_3Cone = LB_Pos["3Cone"].mean()
LB_Shut = LB_Pos["Shuttle"].mean()

# %%
#EXPERIMENTING WITH GRAPHS
plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
positions = ('Quarterbacks', 'Runningbacks', 'Receivers', 'Offensive Line', 'Tight End',
             'Defensive Line', 'Linebackers', 'Defensive Backs')
y_pos = (positions)
ConeTimes = [QB_3Cone, RB_3Cone, WR_3Cone, OL_3Cone, TE_3Cone, DL_3Cone, LB_3Cone, DB_3Cone]

plt.xlim(6.6,8)


ax.barh(y_pos, ConeTimes, align='center',
        color='green', ecolor='black')
ax.set_yticks(y_pos)
ax.set_yticklabels(positions)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Time (in seconds)')
ax.set_title('Average 3Cone Time')

plt.show()

plt.savefig('Avg_3Cone')

# %%
#EXPERIMENTING WITH GRAPHS
plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
positions = ('Quarterbacks', 'Runningbacks', 'Receivers', 'Offensive Line', 'Tight End',
             'Defensive Line', 'Linebackers', 'Defensive Backs')
y_pos = (positions)
ShuttleTimes = [QB_Shut, RB_Shut, WR_Shut, OL_Shut, TE_Shut, DL_Shut, LB_Shut, DB_Shut]

plt.xlim(4,4.8)

ax.barh(y_pos, ShuttleTimes, align='center',
        color='green', ecolor='black')
ax.set_yticks(y_pos)
ax.set_yticklabels(positions)
ax.invert_yaxis()
ax.set_xlabel('Time (in seconds)')
ax.set_title('Average Shuttle Time')

plt.show()

plt.savefig('Avg_Shuttle')

# %%
#EXPERIMENTING WITH GRAPHS
plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
positions = ('Quarterbacks', 'Runningbacks', 'Receivers', 'Offensive Line', 'Tight End',
             'Defensive Line', 'Linebackers', 'Defensive Backs')
y_pos = (positions)
FortyTimes = [QB_40, RB_40, WR_40, OL_40, TE_40, DL_40, LB_40, DB_40]

plt.xlim(4,5.5)

ax.barh(y_pos, FortyTimes, align='center',
        color='green', ecolor='black')
ax.set_yticks(y_pos)
ax.set_yticklabels(positions)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Time (in seconds)')
ax.set_title('Average 40 Time')

plt.show()

plt.savefig('Avg_40Yd')

# %%
#EXPERIMENTING WITH GRAPHS
plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
positions = ('Quarterbacks', 'Runningbacks', 'Receivers', 'Offensive Line', 'Tight End',
             'Defensive Line', 'Linebackers', 'Defensive Backs')
y_pos = (positions)
BroadJumpDistance = [QB_Jump, RB_Jump, WR_Jump, OL_Jump, TE_Jump, DL_Jump, LB_Jump, DB_Jump]

plt.xlim(90,125)

ax.barh(y_pos, BroadJumpDistance, align='center',
        color='green', ecolor='black')
ax.set_yticks(y_pos)
ax.set_yticklabels(positions)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Distance (in inches)')
ax.set_title('Average Broad Jump Distance')

plt.show()

plt.savefig('Avg_BroadJump')

# %%
#EXPERIMENTING WITH GRAPHS
plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
positions = ('Quarterbacks', 'Runningbacks', 'Receivers', 'Offensive Line', 'Tight End',
             'Defensive Line', 'Linebackers', 'Defensive Backs')
y_pos = (positions)
BenchReps = [QB_Bench, RB_Bench, WR_Bench, OL_Bench, TE_Bench, DL_Bench, LB_Bench, DB_Bench]

plt.xlim(10,28)

ax.barh(y_pos, BenchReps, align='center',
        color='green', ecolor='black')
ax.set_yticks(y_pos)
ax.set_yticklabels(positions)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Reps')
ax.set_title('Average Bench Press Reps')

plt.show()

plt.savefig('Avg_Bench')

# %%
#EXPERIMENTING WITH GRAPHS
plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
positions = ('Quarterbacks', 'Runningbacks', 'Receivers', 'Offensive Line', 'Tight End',
             'Defensive Line', 'Linebackers', 'Defensive Backs')
y_pos = (positions)
VerticalJump = [QB_Vert, RB_Vert, WR_Vert, OL_Vert, TE_Vert, DL_Vert, LB_Vert, DB_Vert]

plt.xlim(25,40)

ax.barh(y_pos, VerticalJump, align='center',
        color='green', ecolor='black')
ax.set_yticks(y_pos)
ax.set_yticklabels(positions)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Height (in inches)')
ax.set_title('Average Vertical Jump')

plt.show()

plt.savefig('Avg_Vertical')

# %%
#Offensive line and defensive line
OL = plt.scatter(master_OL['Broad Jump'], master_OL['Shuttle'], s=master_OL['ProBowl Appearances']*100, color = ['gold'], edgecolor = 'black', alpha = .75)
DL = plt.scatter(master_DL['Broad Jump'], master_DL['Shuttle'], s=master_DL['ProBowl Appearances']*100, color = ['coral'], edgecolor = 'black', alpha = .75)
plt.grid()

#Labeling your graph. 
plt.title('Correlation between Broad Jump and Shuttle (Positions:OL&DL)')
plt.xlabel('Broad Jump Distance (Inches)')
plt.ylabel('Shuttle Time (Seconds)')

plt.legend((OL,DL),
           ('Offensive Line','Defensive Line'),
           scatterpoints=1,
           loc='upper right',
           ncol=3,
           fontsize=8)

plt.text(127,4.8,"Note: \nCircle size correlates with pro bowl appearances.", fontsize = 10)

#Observations; There is a CLEAR correlation between broad jump distance and defensive line pro bowl appearances;
#NOTE: Find an additional drill to pair with broad jump to see if there are correlations


plt.savefig('OL_DL_BroadJump_Shuttle')
plt.show()

# %%
#3Cone and Broadjump; DB and WR
DB = plt.scatter(master_DB['3Cone'], master_DB['Broad Jump'], s=master_DB['ProBowl Appearances']*100, color = ['gold'], edgecolor = 'black', alpha = .75)
WR = plt.scatter(master_WR['3Cone'], master_WR['Broad Jump'], s=master_WR['ProBowl Appearances']*100, color = ['coral'], edgecolor = 'black', alpha = .75)
plt.grid()

#Labeling your graph. 
plt.title('Correlation between 3Cone and Broad Jump (Positions:DB&WR)')
plt.xlabel('3 Cone Time (Seconds)')
plt.ylabel('Broad Jump Distance (Inches)')

plt.legend((DB,WR),
           ('Defensive Backs','Wide Receivers'),
           scatterpoints=1,
           loc='upper right',
           ncol=3,
           fontsize=8)

plt.text(7.5,130,"Note: \nCircle size correlates with pro bowl appearances.", fontsize = 10)

plt.savefig('DB_WR_BroadJump_3Cone')

#Observations; can see that a the sweet spot for Broad Jump was between 120 and 130 for most PB appearances
#Observations; sweet spot for 3cone time was a maximum of 7 seconds

# %%
#Speed and athletic ability
LB = plt.scatter(master_LB['40YD'], master_LB['Broad Jump'], s=master_LB['ProBowl Appearances']*100, color = ['gold'], edgecolor = 'black', alpha = .75)
WR = plt.scatter(master_WR['40YD'], master_WR['Broad Jump'], s=master_WR['ProBowl Appearances']*100, color = ['coral'], edgecolor = 'black', alpha = .75)
DB = plt.scatter(master_DB['40YD'], master_DB['Broad Jump'], s=master_DB['ProBowl Appearances']*100, color = ['blue'], edgecolor = 'black', alpha = .75)
QB = plt.scatter(master_QB['40YD'], master_QB['Broad Jump'], s=master_QB['ProBowl Appearances']*100, color = ['purple'], edgecolor = 'black', alpha = .75)
RB = plt.scatter(master_RB['40YD'], master_RB['Broad Jump'], s=master_RB['ProBowl Appearances']*100, color = ['black'], edgecolor = 'black', alpha = .75)
TE = plt.scatter(master_TE['40YD'], master_TE['Broad Jump'], s=master_TE['ProBowl Appearances']*100, color = ['brown'], edgecolor = 'black', alpha = .75)
plt.grid()

#Labeling your graph. 
plt.title('Correlation between 40yd Dash and Broad Jump (Positions:ALL)')
plt.xlabel('40 Yard Time (Seconds)')
plt.ylabel('Broad Jump Distance (Inches)')

plt.legend((LB,WR,DB,QB,RB,TE),
           ('Linebackers','Wide Receivers','Defensive Backs','Quarterbacks','Runningbacks','Tight Ends'),
           scatterpoints=1,
           loc='upper right',
           ncol=3,
           fontsize=8)

plt.text(5.1,130,"Note: \nCircle size correlates with pro bowl appearances.", fontsize = 10)

plt.savefig('GeneralAth_40Yd_BroadJump')
#Observations; can see that a the sweet spot for Broad Jump was between 120 and 130 for most PB appearances
#Observations; sweet spot for 3cone time was a maximum of 7 seconds

#Speed and athleticism is of the essence and players who ran a 40 Yard in less than 4.7 sec and have a broad jump of at least 110
#have a bigger chance of making it to the Probowl.

#Here we look at general athleticism needed to succeed in NFL;
#Biggest correlation between a minimum of 4.6 second 40 yard; and 120 to 130 range of broad jump
#Needed; legend guide for color -> position | Title: Correlation between Broad Jump and 40 Yard. 
plt.show()

# %%
#Weight and Strength
OL = plt.scatter(master_OL['Wt'], master_OL['BenchReps'], s=master_OL['ProBowl Appearances']*100, color = ['red'], edgecolor = 'black', alpha = .75)
DL = plt.scatter(master_DL['Wt'], master_DL['BenchReps'], s=master_DL['ProBowl Appearances']*100, color = ['green'], edgecolor = 'black', alpha = .75)
plt.grid()

#Labeling your graph. 
plt.title('Correlation between Weight and Bench (Positions:OL&DL)')
plt.xlabel('Weight (Pounds)')
plt.ylabel('Bench Reps')

plt.legend((OL,DL),
           ('Offensive Line','Defensive Line'),
           scatterpoints=1,
           loc='upper right',
           ncol=3,
           fontsize=8)

plt.text(352,35,"Note: \nCircle size correlates with pro bowl appearances.", fontsize = 10)

plt.savefig('OL_DL_Weight_Bench')

#Defensive and Offensive Line - Players in these position are very strong and build like a truck.
#For these positions/players to make it to the Probowl, there is a correlation with weight between 
#280 and 320 and also being able to do Bench press reps from 20 to 35

##Here we look at weight and bench press in the trenchs (Offensive Line and Defensive Line);
#Biggest correlation between of a weight between 300-320 and bench of 25-30.
#Needed; legend guide for color -> position | Title: Correlation between weight and bench press (Offensive Line and Defensive Line)

# %%
TE = plt.scatter(master_TE['40YD'], master_TE['Broad Jump'], s=master_TE['ProBowl Appearances']*100, color = ['gold'], edgecolor = 'black', alpha = .75)
LB = plt.scatter(master_LB['40YD'], master_LB['Broad Jump'], s=master_LB['ProBowl Appearances']*100, color = ['coral'], edgecolor = 'black', alpha = .75)
RB = plt.scatter(master_RB['40YD'], master_RB['Broad Jump'], s=master_RB['ProBowl Appearances']*100, color = ['green'], edgecolor = 'black', alpha = .75)

plt.grid()

#Labeling your graph. 
plt.title('Correlation between Broad Jump and 40 yd Dash (Positions:TE&LB&RB)')
plt.xlabel('40 Yard Time (Seconds)')
plt.ylabel('Broad Jump Distance (Inches)')

plt.legend((TE, LB, RB),
           ('Tight End', 'Linebacker', 'Runningback'),
           scatterpoints=1,
           loc='upper right',
           ncol=3,
           fontsize=8)

plt.text(5.05,130,"Note: \nCircle size correlates with pro bowl appearances.", fontsize = 10)

plt.savefig('TE_LB_RB_BroadJump_40Yd')

# %%
DB = plt.scatter(master_DB['Vertical'], master_DB['Broad Jump'], s=master_DB['ProBowl Appearances']*100, color = ['gold'], edgecolor = 'black', alpha = .75)
WR = plt.scatter(master_WR['Vertical'], master_WR['Broad Jump'], s=master_WR['ProBowl Appearances']*100, color = ['coral'], edgecolor = 'black', alpha = .75)
plt.grid()

#Labeling your graph. 
plt.title('Correlation between Vertical and Broad Jump (Positions:DB&WR)')
plt.xlabel('Vertical (Inches)')
plt.ylabel('Broad Jump Distance (Inches)')

plt.legend((DB,WR),
           ('Defensive Backs','Wide Receivers'),
           scatterpoints=1,
           loc='upper right',
           ncol=3,
           fontsize=8)

plt.text(46,130,"Note: \nCircle size correlates with pro bowl appearances.", fontsize = 10)

plt.savefig('DB_WR_Vertical_BroadJump')

#Observations; can see that a the sweet spot for Broad Jump was between 120 and 130 for most PB appearances
#Observations; sweet spot for 3cone time was a maximum of 7 seconds

# %%
#Weight and Strength
OL = plt.scatter(master_OL['Wt'], master_OL['40YD'], s=master_OL['ProBowl Appearances']*100, color = ['red'], edgecolor = 'black', alpha = .75)
DL = plt.scatter(master_DL['Wt'], master_DL['40YD'], s=master_DL['ProBowl Appearances']*100, color = ['green'], edgecolor = 'black', alpha = .75)
plt.grid()

#Labeling your graph. 
plt.title('Correlation between Weight and 40YD (Positions:OL&DL)')
plt.xlabel('Weight (Pounds)')
plt.ylabel('40 YD Time (Seconds)')

plt.legend((OL,DL),
           ('Offensive Line','Defensive Line'),
           scatterpoints=1,
           loc='upper right',
           ncol=3,
           fontsize=8)

plt.text(352,5.2,"Note: \nCircle size correlates with pro bowl appearances.", fontsize = 10)

plt.savefig('OL_DL_Weight_40YD')
